# %%
import pandas as pd
import numpy as np

# %%
train_df = pd.read_csv('data/train.csv')

# %%
test_df = pd.read_csv('data/test.csv')

# %% [markdown]
# ## Feature Engineering

# %%
print("The lowest date in the train data set is {} and the highest {}.".format(train_df['Date'].min(),train_df['Date'].max()))
print("The lowest date in the test data set is {} and the highest {}.".format(test_df['Date'].min(),test_df['Date'].max()))
# Out:
# The lowest date in the train data set is 2020-01-23 and the highest 2020-06-02.
# The lowest date in the test data set is 2020-04-27 and the highest 2020-06-10.

# %%
train_df.rename(columns={'Province_State':'State','Country_Region':'Country'}, inplace=True)
test_df.rename(columns={'Province_State':'State','Country_Region':'Country'}, inplace=True)

# %%
#function for replacing all the missings in the state column
def missings(state, country):
    return country if pd.isna(state) == True else state

# %%
#if there are no states specified for a country, the missing is replaced with the country´s name
train_df['State'] = train_df.apply(lambda x: missings(x['State'],x['Country']),axis=1)
test_df['State'] = test_df.apply(lambda x: missings(x['State'],x['Country']),axis=1)

# %%
print("In our data set are {} countries and {} states.".format(train_df['Country'].nunique(),train_df['State'].nunique()))
# Out:
# In our data set are 187 countries and 319 states.

# %%
train_df.head()
# Out:
#    Id County        State      Country  Population    Weight        Date  \
# 0   1    NaN  Afghanistan  Afghanistan    27657145  0.058359  2020-01-23
# 1   2    NaN  Afghanistan  Afghanistan    27657145  0.583587  2020-01-23
# 2   3    NaN  Afghanistan  Afghanistan    27657145  0.058359  2020-01-24
# 3   4    NaN  Afghanistan  Afghanistan    27657145  0.583587  2020-01-24
# 4   5    NaN  Afghanistan  Afghanistan    27657145  0.058359  2020-01-25
#
#            Target  TargetValue
# 0  ConfirmedCases          0.0
# 1      Fatalities          0.0
# 2  ConfirmedCases          0.0
# 3      Fatalities          0.0
# 4  ConfirmedCases          0.0

# %%
train_df['Date'] = pd.to_datetime(train_df['Date'])

# %%
mask = (train_df['Date'] > '2020-05-01')

# %%
df = train_df.loc[mask]

# %%
df.head()
# Out:
#       Id County        State      Country  Population    Weight       Date  \
# 200  201    NaN  Afghanistan  Afghanistan    27657145  0.058359 2020-05-02
# 201  202    NaN  Afghanistan  Afghanistan    27657145  0.583587 2020-05-02
# 202  203    NaN  Afghanistan  Afghanistan    27657145  0.058359 2020-05-03
# 203  204    NaN  Afghanistan  Afghanistan    27657145  0.583587 2020-05-03
# 204  205    NaN  Afghanistan  Afghanistan    27657145  0.058359 2020-05-04
#
#              Target  TargetValue
# 200  ConfirmedCases        134.0
# 201      Fatalities          4.0
# 202  ConfirmedCases        235.0
# 203      Fatalities         13.0
# 204  ConfirmedCases        190.0

# %%
confirmed_cases_df = df[df['Target']=='ConfirmedCases'][['Id', 'County', 'State', 'Country', 'Population','Weight', 'Date','TargetValue']]
fatalities_df = df[df['Target']=='Fatalities'][['Id', 'County', 'State', 'Country', 'Population','Weight', 'Date','TargetValue']]

# %%
confirmed_cases_df.head()
# Out:
#       Id County        State      Country  Population    Weight       Date  \
# 200  201    NaN  Afghanistan  Afghanistan    27657145  0.058359 2020-05-02
# 202  203    NaN  Afghanistan  Afghanistan    27657145  0.058359 2020-05-03
# 204  205    NaN  Afghanistan  Afghanistan    27657145  0.058359 2020-05-04
# 206  207    NaN  Afghanistan  Afghanistan    27657145  0.058359 2020-05-05
# 208  209    NaN  Afghanistan  Afghanistan    27657145  0.058359 2020-05-06
#
#      TargetValue
# 200        134.0
# 202        235.0
# 204        190.0
# 206        330.0
# 208        168.0

# %%
fatalities_df.head()
# Out:
#       Id County        State      Country  Population    Weight       Date  \
# 201  202    NaN  Afghanistan  Afghanistan    27657145  0.583587 2020-05-02
# 203  204    NaN  Afghanistan  Afghanistan    27657145  0.583587 2020-05-03
# 205  206    NaN  Afghanistan  Afghanistan    27657145  0.583587 2020-05-04
# 207  208    NaN  Afghanistan  Afghanistan    27657145  0.583587 2020-05-05
# 209  210    NaN  Afghanistan  Afghanistan    27657145  0.583587 2020-05-06
#
#      TargetValue
# 201          4.0
# 203         13.0
# 205          5.0
# 207          5.0
# 209          9.0

# %%
confirmed_cases_df.to_csv('data/confirmed_cases.csv')

# %%
fatalities_df.to_csv('data/fatalities.csv')

# %%
result = pd.merge(confirmed_cases_df, fatalities_df, on=['Date', 'Country'])

# %%
result.head()
# Out:
#    Id_x County_x      State_x      Country  Population_x  Weight_x       Date  \
# 0   201      NaN  Afghanistan  Afghanistan      27657145  0.058359 2020-05-02
# 1   203      NaN  Afghanistan  Afghanistan      27657145  0.058359 2020-05-03
# 2   205      NaN  Afghanistan  Afghanistan      27657145  0.058359 2020-05-04
# 3   207      NaN  Afghanistan  Afghanistan      27657145  0.058359 2020-05-05
# 4   209      NaN  Afghanistan  Afghanistan      27657145  0.058359 2020-05-06
#
#    TargetValue_x  Id_y County_y      State_y  Population_y  Weight_y  \
# 0          134.0   202      NaN  Afghanistan      27657145  0.583587
# 1          235.0   204      NaN  Afghanistan      27657145  0.583587
# 2          190.0   206      NaN  Afghanistan      27657145  0.583587
# 3          330.0   208      NaN  Afghanistan      27657145  0.583587
# 4          168.0   210      NaN  Afghanistan      27657145  0.583587
#
#    TargetValue_y
# 0            4.0
# 1           13.0
# 2            5.0
# 3            5.0
# 4            9.0

# %%
intermediate_data = result[['Id_x', 'County_x', 'State_x', 'Country', 
                  'Population_x','Weight_x', 'Date','TargetValue_x', 'TargetValue_y']]

# %%
import gc
del result
del train_df
del confirmed_cases_df
del fatalities_df
gc.collect()
intermediate_data.rename(columns={'TargetValue_x':'ConfirmedCases', 
                       'TargetValue_y':'Fatalities',
                       'Id_x': 'Id', 
                       'County_x': 'County', 
                       'State_x': 'State', 
                       'Population_x': 'Population',
                       'Weight_x': 'Weight',}, inplace=True)

# %%
intermediate_data.head()
# Out:
#     Id County        State      Country  Population    Weight       Date  \
# 0  201    NaN  Afghanistan  Afghanistan    27657145  0.058359 2020-05-02
# 1  203    NaN  Afghanistan  Afghanistan    27657145  0.058359 2020-05-03
# 2  205    NaN  Afghanistan  Afghanistan    27657145  0.058359 2020-05-04
# 3  207    NaN  Afghanistan  Afghanistan    27657145  0.058359 2020-05-05
# 4  209    NaN  Afghanistan  Afghanistan    27657145  0.058359 2020-05-06
#
#    ConfirmedCases  Fatalities
# 0           134.0         4.0
# 1           235.0        13.0
# 2           190.0         5.0
# 3           330.0         5.0
# 4           168.0         9.0

# %%
# Confirmed cases from June 1st
df_confirmedcases = intermediate_data.groupby(['Country','State']).max().groupby('Country').sum().sort_values(by='ConfirmedCases', ascending=False).reset_index().drop(columns='Id')
df_confirmedcases[:20].set_index('Country').style.background_gradient(cmap='Oranges')
# Out:
# <style  type="text/css" >
#     #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row0_col0 {
#             background-color:  #fd8e3d;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row0_col1 {
#             background-color:  #7f2704;
#             color:  #f1f1f1;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row0_col2 {
#             background-color:  #7f2704;
#             color:  #f1f1f1;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row0_col3 {
#             background-color:  #7f2704;
#             color:  #f1f1f1;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row1_col0 {
#             background-color:  #fee0c3;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row1_col1 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row1_col2 {
#             background-color:  #fda55f;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row1_col3 {
#             background-color:  #fff4e9;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row2_col0 {
#             background-color:  #fee8d2;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row2_col1 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row2_col2 {
#             background-color:  #fee6ce;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row2_col3 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row3_col0 {
#             background-color:  #7f2704;
#             color:  #f1f1f1;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row3_col1 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row3_col2 {
#             background-color:  #feead6;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row3_col3 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row4_col0 {
#             background-color:  #fff3e6;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row4_col1 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row4_col2 {
#             background-color:  #feead6;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row4_col3 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row5_col0 {
#             background-color:  #ffefe0;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row5_col1 {
#             background-color:  #fee2c6;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row5_col2 {
#             background-color:  #ffeede;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row5_col3 {
#             background-color:  #ffeede;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row6_col0 {
#             background-color:  #ffeede;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row6_col1 {
#             background-color:  #fee5cb;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row6_col2 {
#             background-color:  #ffefe0;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row6_col3 {
#             background-color:  #fff3e6;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row7_col0 {
#             background-color:  #fff4e8;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row7_col1 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row7_col2 {
#             background-color:  #fff0e1;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row7_col3 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row8_col0 {
#             background-color:  #fee2c7;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row8_col1 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row8_col2 {
#             background-color:  #fff2e6;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row8_col3 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row9_col0 {
#             background-color:  #feead6;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row9_col1 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row9_col2 {
#             background-color:  #fff2e6;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row9_col3 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row10_col0 {
#             background-color:  #ffefdf;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row10_col1 {
#             background-color:  #fee5cc;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row10_col2 {
#             background-color:  #fff2e6;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row10_col3 {
#             background-color:  #ffefe0;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row11_col0 {
#             background-color:  #ffeedd;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row11_col1 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row11_col2 {
#             background-color:  #fff3e7;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row11_col3 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row12_col0 {
#             background-color:  #fff1e4;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row12_col1 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row12_col2 {
#             background-color:  #fff4e8;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row12_col3 {
#             background-color:  #fff5ea;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row13_col0 {
#             background-color:  #fee6cf;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row13_col1 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row13_col2 {
#             background-color:  #fff4e8;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row13_col3 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row14_col0 {
#             background-color:  #fff3e6;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row14_col1 {
#             background-color:  #fff5eb;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row14_col2 {
#             background-color:  #fff4e8;
#             color:  #000000;
#         }    #T_56a6351a_a8e2_11ea_8ca0_186590d40d63row14_col3 {
#             background-color:  #fff5eb;

# %%
print("The lowest date in the train data set is {} and the highest {}.".format(intermediate_data['Date'].min(),intermediate_data['Date'].max()))
# Out:
# The lowest date in the train data set is 2020-05-02 00:00:00 and the highest 2020-06-02 00:00:00.

# %%
type(intermediate_data)
# Out:
# pandas.core.frame.DataFrame
